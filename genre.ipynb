# %% [markdown]
# <a href="https://colab.research.google.com/github/vikramsuresh01/Music-Genre-Classification/blob/main/genre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pre-Processing

# %%
import numpy as np
import librosa, librosa.display
import matplotlib.pyplot as plt

# %%
example_file = "/content/drive/MyDrive/example.wav"

# %%
# load audio file with Librosa
signal, sample_rate = librosa.load(example_file)

# %%
normalized_signal = (signal - signal.min()) / (signal.max() - signal.min())

# %%
print(normalized_signal)
# Out:
# [0.47658935 0.47628248 0.47615507 ... 0.47676012 0.4767565  0.47675335]

# %%
print(sample_rate)
# Out:
# 22050

# %%
FIG_SIZE = (16,8)

# %%
# Calculate the time axis
duration = len(signal) / sample_rate
time = np.linspace(0, duration, len(signal))

# Plot the waveform
plt.figure()
plt.plot(time, signal)
plt.title('Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

# %%
# Fourier Transform (FFT) - Frequency Domain
fft = np.fft.fft(signal)

# %%
# Calculate the Magnitude (abs values on complex numbers)
spectrum = np.abs(fft)

# %%
# Create the Frequency variable
f = np.linspace(0, sample_rate, len(spectrum))

# %%
# Plot Spectrum
plt.figure(figsize=FIG_SIZE)
plt.plot(f, spectrum, alpha=0.5)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Power Spectrum')

# %%
# Take half of the spectrum and frequency
left_spectrum = spectrum[:int(len(spectrum)/2)]
left_f = f[:int(len(spectrum)/2)]

# %%
# Plot Spectrum
plt.figure(figsize=FIG_SIZE)
plt.plot(left_f, left_spectrum, alpha=0.5)
plt.xlabel("Frequency")
plt.ylabel("Magnitude")
plt.title("Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Power Spectrum')

# %%
# Spectrogram (STFT)
hop_length = 512 # num. of samples
n_fft = 2048 # num. of samples for window

# %%
# Perform STFT
stft = librosa.stft(signal, n_fft=n_fft, hop_length=hop_length)

# %%
# Calculate the Magnitude (abs values on complex numbers)
spectrogram = np.abs(stft)

# %%
# Plot the Spectrogram
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.title("Spectrogram")
# Out:
# Text(0.5, 1.0, 'Spectrogram')

# %%
# Apply Logarithm to get values in Decibels
log_spectrogram = librosa.amplitude_to_db(spectrogram)

# %%
# Plot the Spectrogram in Decibels
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(log_spectrogram, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar(format="%+2.0f dB")
plt.title("Spectrogram (dB)")
# Out:
# Text(0.5, 1.0, 'Spectrogram (dB)')

# %%
# Calculate MFCCs
n_fft = 2048
hop_length = 512
n_mfcc = 13
mfccs = librosa.feature.mfcc(y=signal, sr=sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=n_mfcc)

# Print the shape of MFCCs
print("MFCCs shape:", mfccs.shape)
# Out:
# MFCCs shape: (13, 176)

# %%
# MFCCs (we use 13 MFCCs)
#MFCCs = librosa.feature.mfcc(signal, sample_rate, n_fft=n_fft, hop_length=hop_length, n_mfcc=13)
MFCCs = librosa.feature.mfcc(y=signal,sr=sample_rate, n_mfcc=13, n_fft=n_fft, hop_length=hop_length)

# %%
# Plot MFCCs
plt.figure(figsize=FIG_SIZE)
librosa.display.specshow(MFCCs, sr=sample_rate, hop_length=hop_length)
plt.xlabel("Time")
plt.ylabel("MFCC coefficients")
plt.colorbar()
plt.title("MFCCs")
# Out:
# Text(0.5, 1.0, 'MFCCs')

# %% [markdown]
# Feature-Extraction

# %%
import json
import os
import math

# %%
DATASET_PATH = "/content/drive/MyDrive/genres_original"
JSON_PATH = "/content/drive/MyDrive/genres_original/data_10.json"
SAMPLE_RATE = 22050
TRACK_DURATION = 30 # measured in seconds
SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION

# %%
def save_mfcc(dataset_path, json_path, num_mfcc=13, n_fft=2048, hop_length=512, num_segments=5):
    """Extracts MFCCs from music dataset and saves them into a json file along with genre labels.
        """

    # dictionary to store mapping, labels, and MFCCs
    data = {
        "mapping": [],
        "labels": [],
        "mfcc": []
    }

    samples_per_segment = int(SAMPLES_PER_TRACK / num_segments)
    num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / hop_length)

    # loop through all genre sub-folder
    for i, (dirpath, dirnames, filenames) in enumerate(os.walk(dataset_path)):

        # ensure we're processing a genre sub-folder level
        if dirpath is not dataset_path:

            # save genre label (i.e., sub-folder name) in the mapping
            semantic_label = dirpath.split("/")[-1]
            data["mapping"].append(semantic_label)
            print("\nProcessing: {}".format(semantic_label))

            # process all audio files in genre sub-dir
            for f in filenames:

		# load audio file
                file_path = os.path.join(dirpath, f)
                signal, sample_rate = librosa.load(file_path, sr=SAMPLE_RATE)

                # process all segments of audio file
                for d in range(num_segments):

                    # calculate start and finish sample for current segment
                    start = samples_per_segment * d
                    finish = start + samples_per_segment

                    # extract mfcc
                    mfcc = librosa.feature.mfcc(y=signal[start:finish],sr=sample_rate, n_mfcc=num_mfcc, n_fft=n_fft, hop_length=hop_length)
                    mfcc = mfcc.T

                    # store only mfcc feature with expected number of vectors
                    if len(mfcc) == num_mfcc_vectors_per_segment:
                        data["mfcc"].append(mfcc.tolist())
                        data["labels"].append(i-1)
                        print("{}, segment:{}".format(file_path, d+1))

    # save MFCCs to json file
    with open(json_path, "w") as fp:
        json.dump(data, fp, indent=4)

# %%
save_mfcc(DATASET_PATH, JSON_PATH, num_segments=10)
# Out:
# Streaming output truncated to the last 5000 lines.
#
# Processing: disco
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00000.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00003.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00002.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00004.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00001.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00008.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00006.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00011.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00010.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00012.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00009.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00007.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00014.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00013.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00005.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00016.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00018.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00022.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00021.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00019.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00017.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00020.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00023.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00015.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00027.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00030.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00025.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00033.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00031.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00032.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00028.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00024.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00026.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00029.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00041.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00036.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00040.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00038.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00035.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00034.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00042.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00039.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00037.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00046.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00048.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00047.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00051.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00043.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00045.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00049.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00044.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00052.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00050.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00060.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00061.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00057.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00054.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00059.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00056.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00055.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00053.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00058.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00070.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00069.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00068.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:5
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:6
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:7
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:8
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:9
# /content/drive/MyDrive/genres_original/disco/disco.00064.wav, segment:10
# /content/drive/MyDrive/genres_original/disco/disco.00065.wav, segment:1
# /content/drive/MyDrive/genres_original/disco/disco.00065.wav, segment:2
# /content/drive/MyDrive/genres_original/disco/disco.00065.wav, segment:3
# /content/drive/MyDrive/genres_original/disco/disco.00065.wav, segment:4
# /content/drive/MyDrive/genres_original/disco/disco.00065.wav, segment:5
# ...
# /content/drive/MyDrive/genres_original/jazz/jazz.00075.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00075.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00075.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00075.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00075.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00075.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00075.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00079.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00078.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00081.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00082.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00083.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00080.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00087.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00088.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00086.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00085.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00084.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00089.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00091.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00095.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00093.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00094.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00092.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00090.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00097.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00099.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00098.wav, segment:10
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:1
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:2
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:3
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:4
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:5
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:6
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:7
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:8
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:9
# /content/drive/MyDrive/genres_original/jazz/jazz.00096.wav, segment:10
#
# Processing: .ipynb_checkpoints

# %%
# !pip install --upgrade tensorflow keras

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow import keras
import matplotlib.pyplot as plt
import random

import librosa
import math

# %%
# path to json
DATA_PATH = "/content/drive/MyDrive/genres_original/data_10.json"

# %% [markdown]
# Data Preparation

# %%
def load_data(data_path):

    with open(data_path, "r") as f:
        data = json.load(f)

    # convert lists to numpy arrays
    X = np.array(data["mfcc"])
    y = np.array(data["labels"])

    print("Data succesfully loaded!")

    return  X, y

# %%
# load data
X, y = load_data(DATA_PATH)
# Out:
# Data succesfully loaded!

# %%
X.shape
# Out:
# (9986, 130, 13)

# %%
# create train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %% [markdown]
# Model-Building

# %%
# build network topology
model = keras.Sequential([

    # input layer
    keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

    # 1st dense layer
    keras.layers.Dense(512, activation='relu'),

    # 2nd dense layer
    keras.layers.Dense(256, activation='relu'),

    # 3rd dense layer
    keras.layers.Dense(64, activation='relu'),

    # output layer
    keras.layers.Dense(10, activation='softmax')
])

# %%
# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 1690)              0
#
#  dense (Dense)               (None, 512)               865792
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 1,014,218
# Trainable params: 1,014,218
# Non-trainable params: 0
# _________________________________________________________________

# %%
# train model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 219/219 [==============================] - 7s 26ms/step - loss: 8.1875 - accuracy: 0.3356 - val_loss: 4.5503 - val_accuracy: 0.3655
# Epoch 2/50
# 219/219 [==============================] - 4s 18ms/step - loss: 3.3324 - accuracy: 0.4395 - val_loss: 3.2076 - val_accuracy: 0.4319
# Epoch 3/50
# 219/219 [==============================] - 4s 19ms/step - loss: 2.3474 - accuracy: 0.5066 - val_loss: 2.7698 - val_accuracy: 0.4469
# Epoch 4/50
# 219/219 [==============================] - 5s 25ms/step - loss: 1.7970 - accuracy: 0.5661 - val_loss: 2.4433 - val_accuracy: 0.4740
# Epoch 5/50
# 219/219 [==============================] - 4s 18ms/step - loss: 1.4486 - accuracy: 0.6202 - val_loss: 2.7246 - val_accuracy: 0.4790
# Epoch 6/50
# 219/219 [==============================] - 4s 19ms/step - loss: 1.2060 - accuracy: 0.6584 - val_loss: 2.4254 - val_accuracy: 0.4920
# Epoch 7/50
# 219/219 [==============================] - 5s 22ms/step - loss: 1.0185 - accuracy: 0.6980 - val_loss: 2.3693 - val_accuracy: 0.4913
# Epoch 8/50
# 219/219 [==============================] - 4s 19ms/step - loss: 0.8444 - accuracy: 0.7376 - val_loss: 2.3065 - val_accuracy: 0.4800
# Epoch 9/50
# 219/219 [==============================] - 4s 19ms/step - loss: 0.7147 - accuracy: 0.7734 - val_loss: 2.2326 - val_accuracy: 0.5290
# Epoch 10/50
# 219/219 [==============================] - 5s 25ms/step - loss: 0.6155 - accuracy: 0.7990 - val_loss: 2.3276 - val_accuracy: 0.4997
# Epoch 11/50
# 219/219 [==============================] - 6s 28ms/step - loss: 0.5635 - accuracy: 0.8175 - val_loss: 2.4289 - val_accuracy: 0.5013
# Epoch 12/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.5373 - accuracy: 0.8286 - val_loss: 2.1253 - val_accuracy: 0.5387
# Epoch 13/50
# 219/219 [==============================] - 4s 19ms/step - loss: 0.4641 - accuracy: 0.8496 - val_loss: 2.2213 - val_accuracy: 0.5531
# Epoch 14/50
# 219/219 [==============================] - 5s 23ms/step - loss: 0.3568 - accuracy: 0.8768 - val_loss: 2.2228 - val_accuracy: 0.5511
# Epoch 15/50
# 219/219 [==============================] - 4s 18ms/step - loss: 0
50
# 219/219 [==============================] - 4s 18ms/step - loss: 0.2293 - accuracy: 0.9263 - val_loss: 2.9338 - val_accuracy: 0.5611
# Epoch 40/50
# 219/219 [==============================] - 5s 25ms/step - loss: 0.2490 - accuracy: 0.9236 - val_loss: 2.8909 - val_accuracy: 0.5547
# Epoch 41/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.1400 - accuracy: 0.9544 - val_loss: 2.7369 - val_accuracy: 0.5871
# Epoch 42/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.1343 - accuracy: 0.9587 - val_loss: 2.7083 - val_accuracy: 0.5771
# Epoch 43/50
# 219/219 [==============================] - 6s 25ms/step - loss: 0.0556 - accuracy: 0.9827 - val_loss: 2.5390 - val_accuracy: 0.5988
# Epoch 44/50
# 219/219 [==============================] - 6s 27ms/step - loss: 0.0455 - accuracy: 0.9876 - val_loss: 2.7209 - val_accuracy: 0.5888
# Epoch 45/50
# 219/219 [==============================] - 4s 18ms/step - loss: 0.1151 - accuracy: 0.9668 - val_loss: 3.0745 - val_accuracy: 0.5634
# Epoch 46/50
# 219/219 [==============================] - 4s 19ms/step - loss: 0.1068 - accuracy: 0.9652 - val_loss: 2.7558 - val_accuracy: 0.5881
# Epoch 47/50
# 219/219 [==============================] - 5s 24ms/step - loss: 0.0912 - accuracy: 0.9714 - val_loss: 2.6059 - val_accuracy: 0.6025
# Epoch 48/50
# 219/219 [==============================] - 4s 17ms/step - loss: 0.0922 - accuracy: 0.9702 - val_loss: 2.9732 - val_accuracy: 0.5738
# Epoch 49/50
# 219/219 [==============================] - 4s 19ms/step - loss: 0.1046 - accuracy: 0.9705 - val_loss: 3.2738 - val_accuracy: 0.5454
# Epoch 50/50
# 219/219 [==============================] - 5s 22ms/step - loss: 0.1253 - accuracy: 0.9572 - val_loss: 2.7376 - val_accuracy: 0.6045

# %%
def plot_history(history):

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
# plot accuracy and error as a function of the epochs
plot_history(history)

# %%
# build network topology
model_regularized = keras.Sequential([

    # input layer
    keras.layers.Flatten(input_shape=(X.shape[1], X.shape[2])),

    # 1st dense layer
    keras.layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),

    # 2nd dense layer
    keras.layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),

    # 3rd dense layer
    keras.layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001)),
    keras.layers.Dropout(0.3),

    # output layer
    keras.layers.Dense(10, activation='softmax')
])

# %%
# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model_regularized.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# train model
history = model_regularized.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 6s 20ms/step - loss: 25.9157 - accuracy: 0.1591 - val_loss: 3.7727 - val_accuracy: 0.2737
# Epoch 2/100
# 219/219 [==============================] - 6s 26ms/step - loss: 7.1798 - accuracy: 0.1917 - val_loss: 3.2958 - val_accuracy: 0.2724
# Epoch 3/100
# 219/219 [==============================] - 4s 20ms/step - loss: 4.9187 - accuracy: 0.1834 - val_loss: 3.3510 - val_accuracy: 0.2310
# Epoch 4/100
# 219/219 [==============================] - 4s 20ms/step - loss: 4.0929 - accuracy: 0.1854 - val_loss: 3.3431 - val_accuracy: 0.2220
# Epoch 5/100
# 219/219 [==============================] - 6s 26ms/step - loss: 3.7871 - accuracy: 0.1999 - val_loss: 3.3562 - val_accuracy: 0.2146
# Epoch 6/100
# 219/219 [==============================] - 4s 20ms/step - loss: 3.5895 - accuracy: 0.2076 - val_loss: 3.3415 - val_accuracy: 0.2096
# Epoch 7/100
# 219/219 [==============================] - 4s 19ms/step - loss: 3.5207 - accuracy: 0.2083 - val_loss: 3.2269 - val_accuracy: 0.3001
# Epoch 8/100
# 219/219 [==============================] - 6s 26ms/step - loss: 3
100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.3525 - accuracy: 0.6522 - val_loss: 1.7393 - val_accuracy: 0.5764
# Epoch 78/100
# 219/219 [==============================] - 5s 22ms/step - loss: 1.3334 - accuracy: 0.6569 - val_loss: 1.7507 - val_accuracy: 0.5658
# Epoch 79/100
# 219/219 [==============================] - 5s 24ms/step - loss: 1.3153 - accuracy: 0.6611 - val_loss: 1.7078 - val_accuracy: 0.5734
# Epoch 80/100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.3102 - accuracy: 0.6701 - val_loss: 1.7385 - val_accuracy: 0.5704
# Epoch 81/100
# 219/219 [==============================] - 5s 22ms/step - loss: 1.2797 - accuracy: 0.6765 - val_loss: 1.7256 - val_accuracy: 0.5751
# Epoch 82/100
# 219/219 [==============================] - 5s 25ms/step - loss: 1.2708 - accuracy: 0.6754 - val_loss: 1.7717 - val_accuracy: 0.5674
# Epoch 83/100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.2798 - accuracy: 0.6781 - val_loss: 1.7432 - val_accuracy: 0.5798
# Epoch 84/100
# 219/219 [==============================] - 5s 21ms/step - loss: 1.2732 - accuracy: 0.6803 - val_loss: 1.7401 - val_accuracy: 0.5824
# Epoch 85/100
# 219/219 [==============================] - 5s 24ms/step - loss: 1.2269 - accuracy: 0.6916 - val_loss: 1.6890 - val_accuracy: 0.5854
# Epoch 86/100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.2201 - accuracy: 0.6969 - val_loss: 1.8024 - val_accuracy: 0.5844
# Epoch 87/100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.2155 - accuracy: 0.6964 - val_loss: 1.7397 - val_accuracy: 0.5841
# Epoch 88/100
# 219/219 [==============================] - 6s 28ms/step - loss: 1.2010 - accuracy: 0.6956 - val_loss: 1.7186 - val_accuracy: 0.5804
# Epoch 89/100
# 219/219 [==============================] - 4s 20ms/step - loss: 1.1579 - accuracy: 0.7050 - val_loss: 1.7498 - val_accuracy: 0.5854
# Epoch 90/100
# 219/219 [==============================] - 4s 20ms/step - loss: 1.1611 - accuracy: 0.7103 - val_loss: 1.7535 - val_accuracy: 0.5814
# Epoch 91/100
# 219/219 [==============================] - 6s 26ms/step - loss: 1.1605 - accuracy: 0.7110 - val_loss: 1.7899 - val_accuracy: 0.5831
# Epoch 92/100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.1585 - accuracy: 0.7193 - val_loss: 1.7400 - val_accuracy: 0.5888
# Epoch 93/100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.1423 - accuracy: 0.7147 - val_loss: 1.7537 - val_accuracy: 0.5871
# Epoch 94/100
# 219/219 [==============================] - 6s 26ms/step - loss: 1.1390 - accuracy: 0.7110 - val_loss: 1.7286 - val_accuracy: 0.5854
# Epoch 95/100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.1173 - accuracy: 0.7247 - val_loss: 1.7706 - val_accuracy: 0.5848
# Epoch 96/100
# 219/219 [==============================] - 4s 20ms/step - loss: 1.0884 - accuracy: 0.7315 - val_loss: 1.7051 - val_accuracy: 0.5948
# Epoch 97/100
# 219/219 [==============================] - 6s 26ms/step - loss: 1.0952 - accuracy: 0.7292 - val_loss: 1.7733 - val_accuracy: 0.5801
# Epoch 98/100
# 219/219 [==============================] - 4s 19ms/step - loss: 1.0829 - accuracy: 0.7332 - val_loss: 1.7596 - val_accuracy: 0.5818
# Epoch 99/100
# 219/219 [==============================] - 4s 20ms/step - loss: 1.0615 - accuracy: 0.7351 - val_loss: 1.7526 - val_accuracy: 0.5844
# Epoch 100/100
# 219/219 [==============================] - 6s 26ms/step - loss: 1.0593 - accuracy: 0.7388 - val_loss: 1.7366 - val_accuracy: 0.5911

# %%
# plot accuracy and error as a function of the epochs
plot_history(history)

# %%
# create train, validation and test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=0.2)

# add an axis to input sets
X_train = X_train[..., np.newaxis]
X_validation = X_validation[..., np.newaxis]
X_test = X_test[..., np.newaxis]

# %%
X_train.shape
# Out:
# (5991, 130, 13, 1)

# %%
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# %%
# build the CNN
model_cnn = keras.Sequential()

# 1st conv layer
model_cnn.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
model_cnn.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())

# 2nd conv layer
model_cnn.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))
model_cnn.add(keras.layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())

# 3rd conv layer
model_cnn.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
model_cnn.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
model_cnn.add(keras.layers.BatchNormalization())

# flatten output and feed it into dense layer
model_cnn.add(keras.layers.Flatten())
model_cnn.add(keras.layers.Dense(64, activation='relu'))
model_cnn.add(keras.layers.Dropout(0.3))

# output layer
model_cnn.add(keras.layers.Dense(10, activation='softmax'))

# %%
# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model_cnn.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model_cnn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 128, 11, 32)       320
#
#  max_pooling2d (MaxPooling2D  (None, 64, 6, 32)        0
#  )
#
#  batch_normalization (BatchN  (None, 64, 6, 32)        128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 62, 4, 32)         9248
#
#  max_pooling2d_1 (MaxPooling  (None, 31, 2, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 31, 2, 32)        128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 30, 1, 32)         4128
#
#  max_pooling2d_2 (MaxPooling  (None, 15, 1, 32)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 15, 1, 32)        128
#  hNormalization)
#
#  flatten_2 (Flatten)         (None, 480)               0
#
#  dense_8 (Dense)             (None, 64)                30784
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_9 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 45,514
# Trainable params: 45,322
# Non-trainable params: 192
# _________________________________________________________________

# %%
# train model
history = model_cnn.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 188/188 [==============================] - 18s 82ms/step - loss: 2.5135 - accuracy: 0.2208 - val_loss: 2.0067 - val_accuracy: 0.3057
# Epoch 2/50
# 188/188 [==============================] - 15s 80ms/step - loss: 1.9114 - accuracy: 0.3510 - val_loss: 1.6546 - val_accuracy: 0.4232
# Epoch 3/50
# 188/188 [==============================] - 18s 98ms/step - loss: 1.7097 - accuracy: 0.4069 - val_loss: 1.4970 - val_accuracy: 0.4720
# Epoch 4/50
# 188/188 [==============================] - 15s 82ms/step - loss: 1.5780 - accuracy: 0.4584 - val_loss: 1.4176 - val_accuracy: 0.5067
# Epoch 5/50
# 188/188 [==============================] - 16s 83ms/step - loss: 1.4722 - accuracy: 0.4812 - val_loss: 1.3512 - val_accuracy: 0.5154
# Epoch 6/50
# 188/188 [==============================] - 16s 83ms/step - loss: 1.4041 - accuracy: 0.5061 - val_loss: 1.2991 - val_accuracy: 0.5381
# Epoch 7/50
# 188/188 [==============================] - 15s 82ms/step - loss: 1.3357 - accuracy: 0.5298 - val_loss: 1.2636 - val_accuracy: 0.5481
# Epoch 8/50
# 188/188 [==============================] - 16s 83ms/step - loss: 1.2773 - accuracy: 0.5547 - val_loss: 1.2041 - val_accuracy: 0.5834
# Epoch 9/50
# 188/188 [==============================] - 15s 79ms/step - loss: 1.2351 - accuracy: 0.5637 - val_loss: 1.1766 - val_accuracy: 0.5814
# Epoch 10/50
# 188/188 [==============================] - 15s 82ms/step - loss: 1.1867 - accuracy: 0.5837 - val_loss: 1.1562 - val_accuracy: 0.5895
# Epoch 11/50
# 188/188 [==============================] - 16s 83ms/step - loss: 1.1448 - accuracy: 0.6014 - val_loss: 1.1183 - val_accuracy: 0.6028
# Epoch 12/50
# 188/188 [==============================] - 16s 83ms/step - loss: 1.1240 - accuracy: 0.6126 - val_loss: 1.1065 - val_accuracy: 0.6015
# Epoch 13/50
# 188/188 [==============================] - 15s 80ms/step - loss: 1.0753 - accuracy: 0.6214 - val_loss: 1.0697 - val_accuracy: 0.6202
# 188/188 [==============================] - 15s 79ms/step - loss: 0.6445 - accuracy: 0.7758 - val_loss: 0.8859 - val_accuracy: 0.7076
# Epoch 37/50
# 188/188 [==============================] - 16s 83ms/step - loss: 0.6459 - accuracy: 0.7752 - val_loss: 0.9189 - val_accuracy: 0.6883
# Epoch 38/50
# 188/188 [==============================] - 16s 83ms/step - loss: 0.6242 - accuracy: 0.7853 - val_loss: 0.8998 - val_accuracy: 0.7023
# Epoch 39/50
# 188/188 [==============================] - 16s 83ms/step - loss: 0.6382 - accuracy: 0.7838 - val_loss: 0.8792 - val_accuracy: 0.7196
# Epoch 40/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.6061 - accuracy: 0.7925 - val_loss: 0.8844 - val_accuracy: 0.7096
# Epoch 41/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.5925 - accuracy: 0.7954 - val_loss: 0.8557 - val_accuracy: 0.7176
# Epoch 42/50
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5853 - accuracy: 0.7954 - val_loss: 0.8680 - val_accuracy: 0.7190
# Epoch 43/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.5748 - accuracy: 0.7975 - val_loss: 0.9511 - val_accuracy: 0.6836
# Epoch 44/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.5554 - accuracy: 0.8092 - val_loss: 0.8600 - val_accuracy: 0.7210
# Epoch 45/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.5416 - accuracy: 0.8162 - val_loss: 0.8925 - val_accuracy: 0.6976
# Epoch 46/50
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5375 - accuracy: 0.8159 - val_loss: 0.8580 - val_accuracy: 0.7270
# Epoch 47/50
# 188/188 [==============================] - 15s 80ms/step - loss: 0.5217 - accuracy: 0.8171 - val_loss: 0.8525 - val_accuracy: 0.7123
# Epoch 48/50
# 188/188 [==============================] - 16s 83ms/step - loss: 0.5237 - accuracy: 0.8207 - val_loss: 0.8780 - val_accuracy: 0.7156
# Epoch 49/50
# 188/188 [==============================] - 15s 82ms/step - loss: 0.5060 - accuracy: 0.8269 - val_loss: 0.8890 - val_accuracy: 0.7109
# Epoch 50/50
# 188/188 [==============================] - 15s 79ms/step - loss: 0.5018 - accuracy: 0.8317 - val_loss: 0.8669 - val_accuracy: 0.7163

# %%
# plot accuracy and error as a function of the epochs
plot_history(history)

# %% [markdown]
# Model Evaluation

# %%
# evaluate model on Test Set
test_loss, test_acc = model_cnn.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 79/79 - 2s - loss: 0.8676 - accuracy: 0.7060 - 2s/epoch - 21ms/step
#
# Test accuracy: 0.7060472369194031

# %%
model_cnn.save("Music_Genre_10_CNN")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _update_step_xla while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %%
model_cnn.save("Music_Genre_10_CNN.h5")

# %%
# It can be used to reconstruct the model identically.
reconstructed_model = keras.models.load_model("Music_Genre_10_CNN.h5")

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[100]
y_to_predict = y_test[100]

# %%
X_to_predict.shape
# Out:
# (130, 13, 1)

# %%
print("Real Genre:", y_to_predict)
# Out:
# Real Genre: 3

# %%
# add a dimension to input data for sample - model.predict() expects a 4d array in this case
X_to_predict = X_to_predict[np.newaxis, ...] # array shape (1, 130, 13, 1)

# %%
X_to_predict.shape
# Out:
# (1, 130, 13, 1)

# %%
# perform prediction
prediction = model_cnn.predict(X_to_predict)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", int(predicted_index))
# Out:
# Predicted Genre: 8

# %%
# pick a sample to predict from the test set
X_to_predict = X_test[50]
y_to_predict = y_test[50]

print("Real Genre:", y_to_predict)

X_to_predict = X_to_predict[np.newaxis, ...]

prediction = model_cnn.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", int(predicted_index))
# Out:
# Real Genre: 7
# 1/1 [==============================] - 0s 38ms/step
# Predicted Genre: 1

# %%
len(X_test)
# Out:
# 2497

# %%
for n in range(10):

  i = random.randint(0,len(X_test))
  # pick a sample to predict from the test set
  X_to_predict = X_test[i]
  y_to_predict = y_test[i]

  print("\nReal Genre:", y_to_predict)

  X_to_predict = X_to_predict[np.newaxis, ...]

  prediction = model_cnn.predict(X_to_predict)

  # get index with max value
  predicted_index = np.argmax(prediction, axis=1)

  print("Predicted Genre:", int(predicted_index))
# Out:
# Real Genre: 8
# 1/1 [==============================] - 0s 26ms/step
# Predicted Genre: 8
#
# Real Genre: 0
# 1/1 [==============================] - 0s 28ms/step
# Predicted Genre: 7
#
# Real Genre: 2
# 1/1 [==============================] - 0s 30ms/step
# Predicted Genre: 2
#
# Real Genre: 4
# 1/1 [==============================] - 0s 24ms/step
# Predicted Genre: 7
#
# Real Genre: 1
# 1/1 [==============================] - 0s 24ms/step
# Predicted Genre: 8
#
# Real Genre: 9
# 1/1 [==============================] - 0s 28ms/step
# Predicted Genre: 3
#
# Real Genre: 3
# 1/1 [==============================] - 0s 26ms/step
# Predicted Genre: 3
#
# Real Genre: 5
# 1/1 [==============================] - 0s 24ms/step
# Predicted Genre: 5
#
# Real Genre: 4
# 1/1 [==============================] - 0s 31ms/step
# Predicted Genre: 4
#
# Real Genre: 2
# 1/1 [==============================] - 0s 24ms/step
# Predicted Genre: 3

# %%
# Audio files pre-processing
def process_input(audio_file, track_duration):

  SAMPLE_RATE = 22050
  NUM_MFCC = 13
  N_FTT=2048
  HOP_LENGTH=512
  TRACK_DURATION = track_duration # measured in seconds
  SAMPLES_PER_TRACK = SAMPLE_RATE * TRACK_DURATION
  NUM_SEGMENTS = 10

  samples_per_segment = int(SAMPLES_PER_TRACK / NUM_SEGMENTS)
  num_mfcc_vectors_per_segment = math.ceil(samples_per_segment / HOP_LENGTH)

  signal, sample_rate = librosa.load(audio_file, sr=SAMPLE_RATE)

  for d in range(10):

    # calculate start and finish sample for current segment
    start = samples_per_segment * d
    finish = start + samples_per_segment

    # extract mfcc
    mfcc = librosa.feature.mfcc(y=signal[start:finish],sr=sample_rate, n_mfcc=NUM_MFCC, n_fft=n_fft, hop_length=hop_length)
    mfcc = mfcc.T

    return mfcc

# %%
genre_dict = {0:"hiphop",1:"country",2:"jazz",3:"classical",4:"metal",5:"pop",6:"rock",7:"blues",8:"reggae",9:"disco"}

# %%
new_input_mfcc = process_input("/content/drive/MyDrive/Dee Yan-Key - Carousel Ride.mp3", 30)

# %%
type(new_input_mfcc)
# Out:
# numpy.ndarray

# %%
new_input_mfcc.shape
# Out:
# (130, 13)

# %%
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape
# Out:
# (1, 130, 13, 1)

# %%
prediction = model_cnn.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 35ms/step
# Predicted Genre: country

# %%
new_input_mfcc = process_input("/content/Filmy Ghost (Sábila Orbe) - KD6-3.7.mp3", 30)

# %%
X_to_predict = new_input_mfcc[np.newaxis, ..., np.newaxis]
X_to_predict.shape
# Out:
# (1, 130, 13, 1)

# %%
prediction = model_cnn.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 27ms/step
# Predicted Genre: jazz

# %%
new_input_mfcc = process_input("/content/Soularflair - Cue 2a - chug, metal, chaotic solo (May The Bridges I Burn Light The Way).mp3", 30)

# %%
prediction = model_cnn.predict(X_to_predict)

# get index with max value
predicted_index = np.argmax(prediction, axis=1)

print("Predicted Genre:", genre_dict[int(predicted_index)])
# Out:
# 1/1 [==============================] - 0s 46ms/step
# Predicted Genre: jazz
